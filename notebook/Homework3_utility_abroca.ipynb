# %% [markdown]
# **This notebook shows the usage of how to visualize the abroca slice on a random dataset**

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from Homework3_compute_and_plot_abroca import compute_abroca

# %%
# Random dataframe to show how the utility function is used.
# pred-prob: probabilistic classification values, 
# p_attribute: protected attribute (0, 1)
# label: true label
df = pd.DataFrame(np.random.rand(100, 1), columns=['pred-prob'])
df['p_attribute'] = np.random.randint(0,2, size=len(df))
df['label'] = np.random.randint(0,2, size=len(df))
df
# Out:
#     pred-prob  p_attribute  label
# 0    0.531358            0      1
# 1    0.451138            0      0
# 2    0.820242            1      1
# 3    0.888047            0      0
# 4    0.079599            0      1
# ..        ...          ...    ...
# 95   0.705519            1      1
# 96   0.034179            1      0
# 97   0.234733            0      0
# 98   0.363459            1      1
# 99   0.217708            1      1
#
# [100 rows x 3 columns]

# %%
slice = compute_abroca(df, 
                       pred_col = 'pred-prob' , 
                       label_col = 'label', 
                       p_attr_col = 'p_attribute',
                       np_p_attr_val = 1, 
                       n_grid = 10000,
                       plot_slices = True, 
                       np_group_name='Non-protected' ,
                       p_group_name='Protected',
                       file_name = f'abroca_test')
